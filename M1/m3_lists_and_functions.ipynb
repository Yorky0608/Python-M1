# %% [markdown]
# 7.4

# %%
things = ["mozzarella", "cinderella", "salmonella"]

# %% [markdown]
# 7.5
# It does not because you are not directly changing the element in the list but simply taking that element and temporarly making it capitalized.

# %%
for thing in things:
    if thing == "cinderella":
        print(thing.capitalize())
# Out:
# Cinderella

# %% [markdown]
# 7.6

# %%
for thing in things:
    if thing == "mozzarella":
        print(thing.upper())
# Out:
# MOZZARELLA

# %% [markdown]
# 7.7

# %%
for thing in things:
    if thing == "salmonella":
        things.remove(thing)

print(things)
# Out:
# ['mozzarella', 'cinderella']

# %% [markdown]
# 9.1

# %%
def good():
    return ["Harry", "Ron", "Hermione"]

print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# 9.2

# %%
odds = []
def get_odds():
    for i in range(1,10,2):
        odds.append(i)
    print(odds)

def get_third():
    return odds[2]

get_odds()
print(get_third())
# Out:
# [1, 3, 5, 7, 9]
# 5
