# %% [markdown]
# 11.1

# %%
from zoo import hours

print(hours())
# Out:
# Open 9-5 daily

# %% [markdown]
# 11.2

# %%
from zoo import hours as menagerie

print(menagerie())
# Out:
# Open 9-5 daily

# %% [markdown]
# 16.2
# It does not handle the quotes and commas.

# %%
from csv import DictReader

with open('books.csv', 'r') as file:
    reader = DictReader(file)
    for row in reader:
        print(row['author'], 'by', row['book'])
# Out:
# J R R Tolkien by The Hobbit
# Lynne Truss by Eats, Shoots & Leaves
