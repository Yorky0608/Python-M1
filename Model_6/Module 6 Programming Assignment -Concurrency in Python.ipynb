# %% [markdown]
# 13.1

# %%
import datetime

today_str = datetime.date.today().isoformat()  # e.g. "2026-02-23"

with open("today.txt", "w", encoding="utf-8") as f:
    f.write(today_str)

# %% [markdown]
# 13.2

# %%
with open("today.txt", "r", encoding="utf-8") as f:
    today_str = f.read()

# %% [markdown]
# 13.3

# %%
print(f"Today is {today_str}")
# Out:
# Today is 2026-02-23

# %% [markdown]
# 15.1

# %%
# !python multiprocess.py
# Out:
# process p3: 2026-02-23 19:00:49.929910
# process p1: 2026-02-23 19:00:50.021192
# process p2: 2026-02-23 19:00:50.412180
